# %%
def function_name(parameters):
  #body of the function

# %%
def adding(a, b):
  return a + b
num1 = int(input())
num2 = int(input())
print(adding(num1, num2))
# Out:
# 3
# 3
# 6

# %%
# Lambda Function

x = lambda a,b : a * b
print(x(2, 6))
# Out:
# 12

# %%
st = "anushka singh"
print(len(st))

st1 = st.upper()
print(st1)

st2 = st.lower()
print(st2)

st3 = st.title()
print(st3)

st4 = st.capitalize()
print(st4)
# Out:
# 13
# ANUSHKA SINGH
# anushka singh
# Anushka Singh
# Anushka singh

# %%
first = " Anushka "
last = " Singh "
#strip

st1 = st.strip()
print(st1)

print(first + last)
# Out:
# Anushka Singh
#  Anushka  Singh

# %%
first = " Anushka "
last = " Singh "

print(first + last)

first = first.strip()
last = last.strip()

print(first + ' ' + last)
# Out:
#  Anushka  Singh
# Anushka Singh

# %%
s = " today "
b = " weather "
c = "is GooD"
ans = s.strip().capitalize() + ", " + b.strip() + " " + c.strip().lower() + "."
print(ans)
print(c.replace("GooD", "bad"))
# Out:
# Today, weather is good.
# is bad

# %%
s = " today "
b = " weather "
c = "is GooD"
ans = s.strip().capitalize() + ", " + b.strip() + " " + c.strip().lower() + "."
print(ans)

ans.find("Today")
ans.find("is")
# Out:
# Today, weather is good.
# 15

# %%
s = " today "
b = " weather "
c = "is GooD"
ans = s.strip().capitalize() + ", " + b.strip() + " " + c.strip().lower() + "."
print(ans)

ans.startswith("Today")
ans.endswith("good")
# Out:
# Today, weather is good.
# False

# %%
a = "hello world"

print(a[6:11])
# Out:
# world

# %%
#Set

st = {43, 90, 21, 21, 45}

print(st)
# Out:
# {21, 90, 43, 45}

# %%
#Dictionary

d = {
    "name": ["Anushka", "Aaradhya", "Sankalp"],
    "age": 21,
    "occupation": "Student",
    "class": 10,
    "Roll No.": 16
}
# print(d['name'][0])

# d['id'] = 1234
# print(d)

del d["name"]
print(d)
# Out:
# {'age': 21, 'occupation': 'Student', 'class': 10, 'Roll No.': 16}
